# %%
import pandas as pd
import ipywidgets
# !pip install plotly
import plotly.express as px
import ipywidgets as widgets

# %%
pip install voila voila-gridstack
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 16.3 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install voila voila-gridstack
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
